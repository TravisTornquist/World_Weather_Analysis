# %% [markdown]
# # Deliverable 1. Retrieve Weather Data.
# ---
# 1. Create a folder called `Weather_Database` to save all the files related with this deliverable.
#
# 2. Save the `Weather_Database_starter_code.ipynb` starter code to the `Weather_Database` folder and rename it as `Weather_Database.ipynb`.
#
# 3. Use the `np.random.uniform` function to generate a new set of 2,000 random latitudes and 2,000 longitudes.
#
# 4. Use the `citipy` module to get the nearest city for each latitude and longitude combination.
#
# 5. Import your OpenWeatherMap's API key and assemble the API call URL as a string variable. Recall to edit the `config.py` file to add your API key; also, it's critical to avoid publishing your API key on your GitHub repository.
#
# 6. Retrieve the following information from the API call:
#
#     * Latitude and longitude
#
#     * Maximum temperature
#
#     * Percent humidity
#
#     * Percent cloudiness
#
#     * Wind speed
#
#     * Weather description (for example, clouds, fog, light rain, clear sky)
#
# 7. Add the weather data to a new DataFrame.
#
# 8. Export the DataFrame as a CSV file, and save it as `WeatherPy_Database.csv` in the `Weather_Database` folder.
# ---

# %%
# Import initial libraries
import numpy as np
import pandas as pd
from citipy import citipy

# %% [markdown]
# ## Use the `np.random.uniform` function to generate a new set of 2,000 random latitudes and 2,000 longitudes.

# %%
# Create a set of random latitude and longitude combinations
lats = np.random.uniform(-90,90,size=2000)
lngs = np.random.uniform(-180,180,size=2000)

# Use the zip function to create an iterator of tuples containing the latitude and longitude combinations
lats_lngs = zip(lats,lngs)

# %%
# Add the latitudes and longitudes to a list
coordinates = list(lats_lngs)

# %% [markdown]
# ## Use the `citipy` module to get the nearest city for each latitude and longitude combination.

# %%
# Create an empty list for holding the cities
cities = []

# Use a for loop to identify nearest city for each latitude and longitude combination using the citipy module
for coordinate in coordinates:
    # Use the citipy module to identify the nearest city to the current coordinate
    city = citipy.nearest_city(coordinate[0],coordinate[1]).city_name
    
    # If the city is unique, then add it to a our cities list
    if city not in cities:
        cities.append(city)

# Print the city count to confirm sufficient count
print(len(cities))
# Out:
# 801

# %% [markdown]
# ## Import your OpenWeatherMap's API key and assemble the API call URL as a string variable. Recall to edit the `config.py` file to add your API key.

# %%
# Import the requests library
import requests

# Import the time library
import time

# Import the datetime module from the datetime library
from datetime import datetime

# Import the OpenWeatherMap's API key
from config import weather_api_key

# %%
# Assemble the OpenWeatherMap's API call
url = "http://api.openweathermap.org/data/2.5/weather?units=Imperial&APPID=" + weather_api_key

# %% [markdown]
# ## Retrieve the following information from the API call.
#
# - The latitude and longitude
# - The Max temperature
# - The % humidity
# - The % cloudiness
# - The Wind speed
# - The Weather description, i.e., cloudy, fog, light rain, clear sky, etc.

# %%
# Create an empty list to hold weather data for each city
city_data = []

# Print a message to indicate that the data retrieval starts
print("Beginning Data Retrieval     ")
print("-----------------------------")

# Create counters and set them to 1
record_count = 1
set_count = 1

# Loop through all the cities in our list to fetch weather data for each city
for i, city in enumerate(cities):
        
    # Group cities in sets of 50 for logging purposes
    if (i % 50 == 0 and i >= 50):
        set_count += 1
        record_count = 1
        time.sleep(60)

    # Create an endpoint URL for each city
    city_url = url + "&q=" + city.replace(" ","+")
    
    # Log the url, record, and set numbers
    print(f"Processing Record {record_count} of Set {set_count} | {city}")

    # Add 1 to the record count
    record_count += 1

    # Run an API request for each of the cities
    try:
        city_weather = requests.get(city_url).json()
        # Parse out the latitude, longitude, max temp, humidity, cloudiness, wind, country, and weather description
        city_lat = city_weather["coord"]["lat"]
        city_lng = city_weather["coord"]["lon"]
        city_max_temp = city_weather["main"]["temp_max"]
        city_humidity = city_weather["main"]["humidity"]
        city_clouds = city_weather["clouds"]["all"]
        city_wind = city_weather["wind"]["speed"]
        city_country = city_weather["sys"]["country"]
        city_weather_list =city_weather["weather"]
        city_weather_description = city_weather_list[0]["description"]
            
        # Append the city information into the city_data list
        city_data.append({"City": city.title(),
                          "Lat": city_lat,
                          "Lng": city_lng,
                          "Max Temp": city_max_temp,
                          "Humidity": city_humidity,
                          "Cloudiness": city_clouds,
                          "Wind Speed": city_wind,
                          "Country": city_country,
                          "Current Description": city_weather_description})
    
    # If an error is experienced, skip the city
    except:
        print("City not found. Skipping...")
        pass

# Indicate that the data retrieval is complete 
print("-----------------------------")
print("Data Retrieval Complete      ")
print("-----------------------------")
# Out:
# Beginning Data Retrieval
# -----------------------------
# Processing Record 1 of Set 1 | khunti
# Processing Record 2 of Set 1 | spornoye
# Processing Record 3 of Set 1 | marion
# Processing Record 4 of Set 1 | castro
# Processing Record 5 of Set 1 | mataura
# Processing Record 6 of Set 1 | baykit
# Processing Record 7 of Set 1 | busselton
# Processing Record 8 of Set 1 | attingal
# Processing Record 9 of Set 1 | rikitea
# Processing Record 10 of Set 1 | cabo san lucas
# Processing Record 11 of Set 1 | north bend
# Processing Record 12 of Set 1 | eureka
# Processing Record 13 of Set 1 | lebu
# Processing Record 14 of Set 1 | lavrentiya
# Processing Record 15 of Set 1 | shimoda
# Processing Record 16 of Set 1 | nemuro
# Processing Record 17 of Set 1 | punta arenas
# Processing Record 18 of Set 1 | naryan-mar
# Processing Record 19 of Set 1 | kieta
# Processing Record 20 of Set 1 | riyadh
# Processing Record 21 of Set 1 | eatonton
# Processing Record 22 of Set 1 | mwinilunga
# Processing Record 23 of Set 1 | tasiilaq
# Processing Record 24 of Set 1 | vaini
# Processing Record 25 of Set 1 | det udom
# Processing Record 26 of Set 1 | georgetown
# Processing Record 27 of Set 1 | longyearbyen
# Processing Record 28 of Set 1 | ahipara
# Processing Record 29 of Set 1 | kvarkeno
# Processing Record 30 of Set 1 | mount gambier
# Processing Record 31 of Set 1 | port alfred
# Processing Record 32 of Set 1 | shaunavon
# Processing Record 33 of Set 1 | kaitangata
# Processing Record 34 of Set 1 | new norfolk
# Processing Record 35 of Set 1 | mys shmidta
# City not found. Skipping...
# Processing Record 36 of Set 1 | hithadhoo
# Processing Record 37 of Set 1 | acajutla
# Processing Record 38 of Set 1 | clyde river
# Processing Record 39 of Set 1 | san patricio
# Processing Record 40 of Set 1 | albany
# Processing Record 41 of Set 1 | nizhneyansk
# City not found. Skipping...
# Processing Record 42 of Set 1 | immokalee
# Processing Record 43 of Set 1 | belogradcik
# City not found. Skipping...
# Processing Record 44 of Set 1 | santa fe
# Processing Record 45 of Set 1 | kutum
# Processing Record 46 of Set 1 | nikolskoye
# Processing Record 47 of Set 1 | dunmore town
# Processing Record 48 of Set 1 | sumkino
# Processing Record 49 of Set 1 | kavieng
# Processing Record 50 of Set 1 | nouakchott
# Processing Record 1 of Set 2 | barentsburg
# City not found. Skipping...
# Processing Record 2 of Set 2 | yar-sale
# Processing Record 3 of Set 2 | codrington
# Processing Record 4 of Set 2 | laguna
# Processing Record 5 of Set 2 | ushuaia
# Processing Record 6 of Set 2 | bosaso
# Processing Record 7 of Set 2 | yurty
# Processing Record 8 of Set 2 | bluff
# Processing Record 9 of Set 2 | lixourion
# Processing Record 10 of Set 2 | zharkent
# Processing Record 11 of Set 2 | barrow
# Processing Record 12 of Set 2 | thompson
# Processing Record 13 of Set 2 | atbasar
# Processing Record 14 of Set 2 | cape town
# Processing Record 15 of Set 2 | bethel
# Processing Record 16 of Set 2 | troitsko-pechorsk
# Processing Record 17 of Set 2 | satipo
# Processing Record 18 of Set 2 | vagur
# Processing Record 19 of Set 2 | norman wells
# Processing Record 20 of Set 2 | buraydah
# Processing Record 21 of Set 2 | qaanaaq
# Processing Record 22 of Set 2 | hobart
# Processing Record 23 of Set 2 | vygonichi
# Processing Record 24 of Set 2 | coruripe
# Processing Record 25 of Set 2 | erzin
# Processing Record 26 of Set 2 | dikson
# Processing Record 27 of Set 2 | urumqi
# Processing Record 28 of Set 2 | kapaa
# Processing Record 29 of Set 2 | muros
# Processing Record 30 of Set 2 | kiunga
# Processing Record 31 of Set 2 | aklavik
# Processing Record 32 of Set 2 | la primavera
# Processing Record 33 of Set 2 | shelburne
# Processing Record 34 of Set 2 | tabasalu
# Processing Record 35 of Set 2 | butaritari
# Processing Record 36 of Set 2 | cockburn town
# Processing Record 37 of Set 2 | bambous virieux
# Processing Record 38 of Set 2 | meulaboh
# Processing Record 39 of Set 2 | presidencia roque saenz pena
# Processing Record 40 of Set 2 | puerto ayora
# Processing Record 41 of Set 2 | padang
# Processing Record 42 of Set 2 | mahebourg
# Processing Record 43 of Set 2 | attawapiskat
# City not found. Skipping...
# Processing Record 44 of Set 2 | korhogo
# Processing Record 45 of Set 2 | mushie
# Processing Record 46 of Set 2 | samusu
# City not found. Skipping...
# Processing Record 47 of Set 2 | chokurdakh
# Processing Record 48 of Set 2 | chuy
# Processing Record 49 of Set 2 | bowen
# Processing Record 50 of Set 2 | kurilsk
# Processing Record 1 of Set 3 | kodiak
# Processing Record 2 of Set 3 | hermanus
# Processing Record 3 of Set 3 | kemi
# Processing Record 4 of Set 3 | zhanakorgan
# Processing Record 5 of Set 3 | kozhevnikovo
# Processing Record 6 of Set 3 | dingle
# Processing Record 7 of Set 3 | tocopilla
# Processing Record 8 of Set 3 | pafos
# Processing Record 9 of Set 3 | saint-philippe
# Processing Record 10 of Set 3 | poykovskiy
# Processing Record 11 of Set 3 | shitkino
# Processing Record 12 of Set 3 | vaitupu
# City not found. Skipping...
# Processing Record 13 of Set 3 | college
# Processing Record 14 of Set 3 | khatanga
# Processing Record 15 of Set 3 | liaqatabad
# Processing Record 16 of Set 3 | tuatapere
# Processing Record 17 of Set 3 | verkhoyansk
# Processing Record 18 of Set 3 | pisco
# Processing Record 19 of Set 3 | carnarvon
# Processing Record 20 of Set 3 | olafsvik
# Processing Record 21 of Set 3 | yellowknife
# Processing Record 22 of Set 3 | hilo
# Processing Record 23 of Set 3 | port lincoln
# Processing Record 24 of Set 3 | pangnirtung
# Processing Record 25 of Set 3 | san jose
# Processing Record 26 of Set 3 | elizabeth city
# Processing Record 27 of Set 3 | beringovskiy
# Processing Record 28 of Set 3 | nabire
# Processing Record 29 of Set 3 | hengshui
# Processing Record 30 of Set 3 | faanui
# Processing Record 31 of Set 3 | hilotongan
# Processing Record 32 of Set 3 | luderitz
# Processing Record 33 of Set 3 | fairbanks
# Processing Record 34 of Set 3 | port elizabeth
# Processing Record 35 of Set 3 | camabatela
# Processing Record 36 of Set 3 | saint-augustin
# Processing Record 37 of Set 3 | awjilah
# Processing Record 38 of Set 3 | jamestown
# Processing Record 39 of Set 3 | atuona
# Processing Record 40 of Set 3 | ojinaga
# Processing Record 41 of Set 3 | bengkulu
# Processing Record 42 of Set 3 | vila franca do campo
# Processing Record 43 of Set 3 | airai
# Processing Record 44 of Set 3 | ponta do sol
# Processing Record 45 of Set 3 | jesup
# Processing Record 46 of Set 3 | port macquarie
# Processing Record 47 of Set 3 | cape coast
# Processing Record 48 of Set 3 | cherskiy
# Processing Record 49 of Set 3 | port blair
# Processing Record 50 of Set 3 | san rafael
# Processing Record 1 of Set 4 | lorengau
# Processing Record 2 of Set 4 | illoqqortoormiut
# City not found. Skipping...
# Processing Record 3 of Set 4 | iqaluit
# Processing Record 4 of Set 4 | tapaua
# City not found. Skipping...
# Processing Record 5 of Set 4 | guiyang
# Processing Record 6 of Set 4 | jalu
# Processing Record 7 of Set 4 | sosnovo-ozerskoye
# Processing Record 8 of Set 4 | puerto cabezas
# Processing Record 9 of Set 4 | comodoro rivadavia
# Processing Record 10 of Set 4 | kamenka
# Processing Record 11 of Set 4 | diego de almagro
# Processing Record 12 of Set 4 | ngukurr
# City not found. Skipping...
# Processing Record 13 of Set 4 | paamiut
# Processing Record 14 of Set 4 | mar del plata
# Processing Record 15 of Set 4 | ambon
# Processing Record 16 of Set 4 | saint george
# Processing Record 17 of Set 4 | coquimbo
# Processing Record 18 of Set 4 | ribeira grande
# Processing Record 19 of Set 4 | svetlaya
# Processing Record 20 of Set 4 | tuktoyaktuk
# Processing Record 21 of Set 4 | nguiu
# City not found. Skipping...
# Processing Record 22 of Set 4 | kamaishi
# Processing Record 23 of Set 4 | moba
# Processing Record 24 of Set 4 | evensk
# Processing Record 25 of Set 4 | honiara
# Processing Record 26 of Set 4 | charters towers
# Processing Record 27 of Set 4 | saint-denis
# Processing Record 28 of Set 4 | haines junction
# Processing Record 29 of Set 4 | bafoulabe
# Processing Record 30 of Set 4 | kadirli
# Processing Record 31 of Set 4 | sretensk
# Processing Record 32 of Set 4 | lompoc
# Processing Record 33 of Set 4 | lazurne
# Processing Record 34 of Set 4 | berlevag
# Processing Record 35 of Set 4 | bargal
# City not found. Skipping...
# Processing Record 36 of Set 4 | la asuncion
# Processing Record 37 of Set 4 | ostrovnoy
# Processing Record 38 of Set 4 | kruisfontein
# Processing Record 39 of Set 4 | merauke
# Processing Record 40 of Set 4 | kineta
# Processing Record 41 of Set 4 | rorvik
# Processing Record 42 of Set 4 | panzhihua
# Processing Record 43 of Set 4 | anisoc
# Processing Record 44 of Set 4 | ihosy
# Processing Record 45 of Set 4 | sinnamary
# Processing Record 46 of Set 4 | bredasdorp
# Processing Record 47 of Set 4 | anju
# Processing Record 48 of Set 4 | lethem
# Processing Record 49 of Set 4 | aurillac
# Processing Record 50 of Set 4 | avarua
# Processing Record 1 of Set 5 | provideniya
# Processing Record 2 of Set 5 | souillac
# Processing Record 3 of Set 5 | teluk nibung
# Processing Record 4 of Set 5 | inuvik
# Processing Record 5 of Set 5 | eha amufu
# Processing Record 6 of Set 5 | agirish
# Processing Record 7 of Set 5 | tecoanapa
# Processing Record 8 of Set 5 | hasaki
# Processing Record 9 of Set 5 | meyungs
# City not found. Skipping...
# Processing Record 10 of Set 5 | sannicolaul mare
# City not found. Skipping...
# Processing Record 11 of Set 5 | emmett
# Processing Record 12 of Set 5 | nanortalik
# Processing Record 13 of Set 5 | amderma
# City not found. Skipping...
# Processing Record 14 of Set 5 | marsh harbour
# Processing Record 15 of Set 5 | guerrero negro
# Processing Record 16 of Set 5 | nanakuli
# Processing Record 17 of Set 5 | trelew
# Processing Record 18 of Set 5 | aguimes
# Processing Record 19 of Set 5 | tres arroyos
# Processing Record 20 of Set 5 | guangyuan
# Processing Record 21 of Set 5 | saint anthony
# Processing Record 22 of Set 5 | rio gallegos
# Processing Record 23 of Set 5 | tanda
# Processing Record 24 of Set 5 | grand centre
# City not found. Skipping...
# Processing Record 25 of Set 5 | piquete
# Processing Record 26 of Set 5 | alexandria
# Processing Record 27 of Set 5 | saldanha
# Processing Record 28 of Set 5 | valparaiso
# Processing Record 29 of Set 5 | high level
# Processing Record 30 of Set 5 | dunedin
# Processing Record 31 of Set 5 | ambilobe
# Processing Record 32 of Set 5 | kavaratti
# Processing Record 33 of Set 5 | dong hoi
# Processing Record 34 of Set 5 | burns lake
# Processing Record 35 of Set 5 | mehamn
# Processing Record 36 of Set 5 | taolanaro
# City not found. Skipping...
# Processing Record 37 of Set 5 | caravelas
# Processing Record 38 of Set 5 | sentyabrskiy
# City not found. Skipping...
# Processing Record 39 of Set 5 | oum hadjer
# Processing Record 40 of Set 5 | ordzhonikidze
# Processing Record 41 of Set 5 | kovernino
# Processing Record 42 of Set 5 | kamina
# Processing Record 43 of Set 5 | victoria
# Processing Record 44 of Set 5 | hyeres
# Processing Record 45 of Set 5 | torbay
# Processing Record 46 of Set 5 | lishui
# Processing Record 47 of Set 5 | prado
# Processing Record 48 of Set 5 | buala
# Processing Record 49 of Set 5 | kichera
# Processing Record 50 of Set 5 | tsihombe
# City not found. Skipping...
# Processing Record 1 of Set 6 | tshikapa
# Processing Record 2 of Set 6 | guipavas
# Processing Record 3 of Set 6 | mamallapuram
# Processing Record 4 of Set 6 | wattegama
# Processing Record 5 of Set 6 | yarovoye
# Processing Record 6 of Set 6 | saint-pierre
# Processing Record 7 of Set 6 | chaplynka
# Processing Record 8 of Set 6 | barentu
# Processing Record 9 of Set 6 | teluknaga
# Processing Record 10 of Set 6 | cidreira
# Processing Record 11 of Set 6 | bella union
# Processing Record 12 of Set 6 | tandlianwala
# Processing Record 13 of Set 6 | saskylakh
# Processing Record 14 of Set 6 | maragogi
# Processing Record 15 of Set 6 | baker city
# Processing Record 16 of Set 6 | sarankhola
# Processing Record 17 of Set 6 | okha
# Processing Record 18 of Set 6 | weatherford
# Processing Record 19 of Set 6 | te anau
# Processing Record 20 of Set 6 | bonavista
# Processing Record 21 of Set 6 | resistencia
# Processing Record 22 of Set 6 | frederico westphalen
# Processing Record 23 of Set 6 | sioux lookout
# Processing Record 24 of Set 6 | harper
# Processing Record 25 of Set 6 | denizli
# Processing Record 26 of Set 6 | akyab
# Processing Record 27 of Set 6 | hendrina
# Processing Record 28 of Set 6 | parsons
# Processing Record 29 of Set 6 | evanston
# Processing Record 30 of Set 6 | hobyo
# Processing Record 31 of Set 6 | wuning
# Processing Record 32 of Set 6 | lufilufi
# Processing Record 33 of Set 6 | cuajinicuilapa
# Processing Record 34 of Set 6 | arona
# Processing Record 35 of Set 6 | marcona
# City not found. Skipping...
# Processing Record 36 of Set 6 | cotacachi
# Processing Record 37 of Set 6 | sambava
# Processing Record 38 of Set 6 | moranbah
# Processing Record 39 of Set 6 | heinola
# Processing Record 40 of Set 6 | viransehir
# Processing Record 41 of Set 6 | pangai
# Processing Record 42 of Set 6 | shiyan
# Processing Record 43 of Set 6 | ucluelet
# Processing Record 44 of Set 6 | mareeba
# Processing Record 45 of Set 6 | palmer
# Processing Record 46 of Set 6 | severo-kurilsk
# Processing Record 47 of Set 6 | quelimane
# Processing Record 48 of Set 6 | chumikan
# Processing Record 49 of Set 6 | maxixe
# Processing Record 50 of Set 6 | inhambane
# Processing Record 1 of Set 7 | upernavik
# Processing Record 2 of Set 7 | poum
# Processing Record 3 of Set 7 | tigil
# Processing Record 4 of Set 7 | westport
# Processing Record 5 of Set 7 | kupang
# Processing Record 6 of Set 7 | arraial do cabo
# Processing Record 7 of Set 7 | hecelchakan
# Processing Record 8 of Set 7 | oksfjord
# Processing Record 9 of Set 7 | taltal
# Processing Record 10 of Set 7 | taunggyi
# Processing Record 11 of Set 7 | aksarka
# Processing Record 12 of Set 7 | sirjan
# Processing Record 13 of Set 7 | saint cloud
# Processing Record 14 of Set 7 | auki
# Processing Record 15 of Set 7 | aberdeen
# Processing Record 16 of Set 7 | east london
# Processing Record 17 of Set 7 | linxia
# Processing Record 18 of Set 7 | leningradskiy
# Processing Record 19 of Set 7 | kayes
# Processing Record 20 of Set 7 | kelso
# Processing Record 21 of Set 7 | kapit
# Processing Record 22 of Set 7 | grand river south east
# City not found. Skipping...
# Processing Record 23 of Set 7 | cayenne
# Processing Record 24 of Set 7 | wajir
# Processing Record 25 of Set 7 | beyneu
# Processing Record 26 of Set 7 | frontera
# Processing Record 27 of Set 7 | sakaiminato
# Processing Record 28 of Set 7 | port-de-paix
# City not found. Skipping...
# Processing Record 29 of Set 7 | harnosand
# Processing Record 30 of Set 7 | guiratinga
# Processing Record 31 of Set 7 | pevek
# Processing Record 32 of Set 7 | narrabri
# Processing Record 33 of Set 7 | seoul
# Processing Record 34 of Set 7 | chapais
# Processing Record 35 of Set 7 | pandan
# Processing Record 36 of Set 7 | shingu
# Processing Record 37 of Set 7 | krasnoselkup
# Processing Record 38 of Set 7 | miri
# Processing Record 39 of Set 7 | rawson
# Processing Record 40 of Set 7 | raudeberg
# Processing Record 41 of Set 7 | aykhal
# Processing Record 42 of Set 7 | tura
# Processing Record 43 of Set 7 | pascagoula
# Processing Record 44 of Set 7 | villa del rosario
# Processing Record 45 of Set 7 | sao gabriel da cachoeira
# Processing Record 46 of Set 7 | jinka
# Processing Record 47 of Set 7 | sedalia
# Processing Record 48 of Set 7 | nsanje
# Processing Record 49 of Set 7 | strone
# Processing Record 50 of Set 7 | constitucion
# Processing Record 1 of Set 8 | jiayuguan
# Processing Record 2 of Set 8 | rio grande
# Processing Record 3 of Set 8 | guanare
# Processing Record 4 of Set 8 | upata
# Processing Record 5 of Set 8 | hearst
# Processing Record 6 of Set 8 | fandriana
# Processing Record 7 of Set 8 | umba
# Processing Record 8 of Set 8 | salvador
# Processing Record 9 of Set 8 | sakakah
# Processing Record 10 of Set 8 | fuyu
# Processing Record 11 of Set 8 | taganak
# Processing Record 12 of Set 8 | kharp
# Processing Record 13 of Set 8 | loukhi
# Processing Record 14 of Set 8 | hamilton
# Processing Record 15 of Set 8 | toungoo
# City not found. Skipping...
# Processing Record 16 of Set 8 | oxford
# Processing Record 17 of Set 8 | lagoa
# Processing Record 18 of Set 8 | mecca
# Processing Record 19 of Set 8 | flinders
# Processing Record 20 of Set 8 | rio hato
# Processing Record 21 of Set 8 | soe
# Processing Record 22 of Set 8 | belyy yar
# Processing Record 23 of Set 8 | lima
# Processing Record 24 of Set 8 | noumea
# Processing Record 25 of Set 8 | byron bay
# Processing Record 26 of Set 8 | ningxiang
# Processing Record 27 of Set 8 | tuy hoa
# Processing Record 28 of Set 8 | vao
# Processing Record 29 of Set 8 | katsuura
# Processing Record 30 of Set 8 | bulgan
# Processing Record 31 of Set 8 | buncrana
# Processing Record 32 of Set 8 | nhulunbuy
# Processing Record 33 of Set 8 | akdepe
# Processing Record 34 of Set 8 | porto novo
# Processing Record 35 of Set 8 | sholapur
# Processing Record 36 of Set 8 | norden
# Processing Record 37 of Set 8 | odweyne
# Processing Record 38 of Set 8 | taoudenni
# Processing Record 39 of Set 8 | bonnyville
# Processing Record 40 of Set 8 | yalutorovsk
# Processing Record 41 of Set 8 | hofn
# Processing Record 42 of Set 8 | necochea
# Processing Record 43 of Set 8 | cajnice
# Processing Record 44 of Set 8 | san roque
# Processing Record 45 of Set 8 | kasongo-lunda
# Processing Record 46 of Set 8 | gardan diwal
# City not found. Skipping...
# Processing Record 47 of Set 8 | ushtobe
# Processing Record 48 of Set 8 | kenai
# Processing Record 49 of Set 8 | maningrida
# Processing Record 50 of Set 8 | ilebo
# Processing Record 1 of Set 9 | baglan
# Processing Record 2 of Set 9 | salinopolis
# Processing Record 3 of Set 9 | isangel
# Processing Record 4 of Set 9 | saint-francois
# Processing Record 5 of Set 9 | mezen
# Processing Record 6 of Set 9 | komsomolskiy
# Processing Record 7 of Set 9 | hun
# Processing Record 8 of Set 9 | kindu
# Processing Record 9 of Set 9 | mogadishu
# Processing Record 10 of Set 9 | xingyi
# Processing Record 11 of Set 9 | avera
# Processing Record 12 of Set 9 | manzanillo
# Processing Record 13 of Set 9 | fortuna
# Processing Record 14 of Set 9 | saryagash
# Processing Record 15 of Set 9 | khandagayty
# Processing Record 16 of Set 9 | salym
# Processing Record 17 of Set 9 | tual
# Processing Record 18 of Set 9 | xiongyue
# Processing Record 19 of Set 9 | kushmurun
# Processing Record 20 of Set 9 | gorom-gorom
# Processing Record 21 of Set 9 | puerto varas
# Processing Record 22 of Set 9 | paracatu
# Processing Record 23 of Set 9 | villa carlos paz
# Processing Record 24 of Set 9 | senanga
# Processing Record 25 of Set 9 | singapore
# Processing Record 26 of Set 9 | selty
# Processing Record 27 of Set 9 | lata
# Processing Record 28 of Set 9 | tomatlan
# Processing Record 29 of Set 9 | vila velha
# Processing Record 30 of Set 9 | mehriz
# Processing Record 31 of Set 9 | hanna
# Processing Record 32 of Set 9 | sal rei
# Processing Record 33 of Set 9 | vardo
# Processing Record 34 of Set 9 | wajima
# Processing Record 35 of Set 9 | karratha
# Processing Record 36 of Set 9 | tezu
# Processing Record 37 of Set 9 | fereydun kenar
# Processing Record 38 of Set 9 | dubrovnik
# Processing Record 39 of Set 9 | humberto de campos
# Processing Record 40 of Set 9 | chicama
# Processing Record 41 of Set 9 | sorong
# Processing Record 42 of Set 9 | ampanihy
# Processing Record 43 of Set 9 | sibolga
# Processing Record 44 of Set 9 | fort nelson
# Processing Record 45 of Set 9 | tripoli
# Processing Record 46 of Set 9 | makakilo city
# Processing Record 47 of Set 9 | general roca
# Processing Record 48 of Set 9 | labuhan
# Processing Record 49 of Set 9 | banfora
# Processing Record 50 of Set 9 | hazorasp
# Processing Record 1 of Set 10 | tucuman
# Processing Record 2 of Set 10 | bilma
# Processing Record 3 of Set 10 | cruden bay
# City not found. Skipping...
# Processing Record 4 of Set 10 | el estor
# Processing Record 5 of Set 10 | grindavik
# Processing Record 6 of Set 10 | ust-nera
# Processing Record 7 of Set 10 | cooma
# Processing Record 8 of Set 10 | santa isabel
# Processing Record 9 of Set 10 | tiksi
# Processing Record 10 of Set 10 | pedernales
# Processing Record 11 of Set 10 | namibe
# Processing Record 12 of Set 10 | yulara
# Processing Record 13 of Set 10 | marawi
# Processing Record 14 of Set 10 | vestmanna
# Processing Record 15 of Set 10 | karwar
# Processing Record 16 of Set 10 | sar-e pul
# Processing Record 17 of Set 10 | kargasok
# Processing Record 18 of Set 10 | bure
# Processing Record 19 of Set 10 | molochnoye
# Processing Record 20 of Set 10 | bako
# Processing Record 21 of Set 10 | abu kamal
# Processing Record 22 of Set 10 | takoradi
# Processing Record 23 of Set 10 | umzimvubu
# City not found. Skipping...
# Processing Record 24 of Set 10 | dali
# Processing Record 25 of Set 10 | anadyr
# Processing Record 26 of Set 10 | storslett
# Processing Record 27 of Set 10 | zhigansk
# Processing Record 28 of Set 10 | salalah
# Processing Record 29 of Set 10 | wote
# Processing Record 30 of Set 10 | touros
# Processing Record 31 of Set 10 | husavik
# Processing Record 32 of Set 10 | aranos
# Processing Record 33 of Set 10 | cabadiangan
# Processing Record 34 of Set 10 | bolobo
# Processing Record 35 of Set 10 | sitka
# Processing Record 36 of Set 10 | nacala
# Processing Record 37 of Set 10 | esperance
# Processing Record 38 of Set 10 | batemans bay
# Processing Record 39 of Set 10 | morehead
# Processing Record 40 of Set 10 | naze
# Processing Record 41 of Set 10 | gold coast
# Processing Record 42 of Set 10 | coihaique
# Processing Record 43 of Set 10 | kahului
# Processing Record 44 of Set 10 | namatanai
# Processing Record 45 of Set 10 | carbonia
# Processing Record 46 of Set 10 | zhanaozen
# Processing Record 47 of Set 10 | yerbogachen
# Processing Record 48 of Set 10 | erenhot
# Processing Record 49 of Set 10 | kanganpur
# Processing Record 50 of Set 10 | tocoa
# Processing Record 1 of Set 11 | yudong
# Processing Record 2 of Set 11 | baringo
# Processing Record 3 of Set 11 | sao filipe
# Processing Record 4 of Set 11 | zyryanka
# Processing Record 5 of Set 11 | cururupu
# Processing Record 6 of Set 11 | leonidion
# City not found. Skipping...
# Processing Record 7 of Set 11 | tchibanga
# Processing Record 8 of Set 11 | belushya guba
# City not found. Skipping...
# Processing Record 9 of Set 11 | mayumba
# Processing Record 10 of Set 11 | srednekolymsk
# Processing Record 11 of Set 11 | nagai
# Processing Record 12 of Set 11 | conneaut
# Processing Record 13 of Set 11 | lolua
# City not found. Skipping...
# Processing Record 14 of Set 11 | cobija
# Processing Record 15 of Set 11 | mandalgovi
# Processing Record 16 of Set 11 | palabuhanratu
# City not found. Skipping...
# Processing Record 17 of Set 11 | hualmay
# Processing Record 18 of Set 11 | sao joao da barra
# Processing Record 19 of Set 11 | bandarbeyla
# Processing Record 20 of Set 11 | balykshi
# Processing Record 21 of Set 11 | oktyabrskoye
# Processing Record 22 of Set 11 | shurugwi
# Processing Record 23 of Set 11 | pontianak
# Processing Record 24 of Set 11 | florence
# Processing Record 25 of Set 11 | ruatoria
# City not found. Skipping...
# Processing Record 26 of Set 11 | namangan
# Processing Record 27 of Set 11 | pytalovo
# Processing Record 28 of Set 11 | ulladulla
# Processing Record 29 of Set 11 | gouyave
# Processing Record 30 of Set 11 | rudnogorsk
# Processing Record 31 of Set 11 | ilulissat
# Processing Record 32 of Set 11 | olinda
# Processing Record 33 of Set 11 | valenca do piaui
# Processing Record 34 of Set 11 | buta
# Processing Record 35 of Set 11 | dubbo
# Processing Record 36 of Set 11 | antibes
# Processing Record 37 of Set 11 | oktyabrskiy
# Processing Record 38 of Set 11 | cam ranh
# Processing Record 39 of Set 11 | dobele
# Processing Record 40 of Set 11 | predivinsk
# Processing Record 41 of Set 11 | maniitsoq
# Processing Record 42 of Set 11 | devonport
# Processing Record 43 of Set 11 | nueva loja
# Processing Record 44 of Set 11 | foumban
# Processing Record 45 of Set 11 | jining
# Processing Record 46 of Set 11 | callaway
# Processing Record 47 of Set 11 | san isidro
# Processing Record 48 of Set 11 | chase
# Processing Record 49 of Set 11 | dor marunt
# Processing Record 50 of Set 11 | manta
# Processing Record 1 of Set 12 | praya
# Processing Record 2 of Set 12 | clifton
# Processing Record 3 of Set 12 | irbil
# Processing Record 4 of Set 12 | teknaf
# Processing Record 5 of Set 12 | durban
# Processing Record 6 of Set 12 | gobabis
# Processing Record 7 of Set 12 | dzilam gonzalez
# Processing Record 8 of Set 12 | broome
# Processing Record 9 of Set 12 | tanete
# Processing Record 10 of Set 12 | prince rupert
# Processing Record 11 of Set 12 | angoche
# Processing Record 12 of Set 12 | yaan
# Processing Record 13 of Set 12 | amboasary
# Processing Record 14 of Set 12 | onguday
# Processing Record 15 of Set 12 | bathsheba
# Processing Record 16 of Set 12 | ambulu
# Processing Record 17 of Set 12 | tarauaca
# Processing Record 18 of Set 12 | yefira
# City not found. Skipping...
# Processing Record 19 of Set 12 | angoram
# Processing Record 20 of Set 12 | diebougou
# Processing Record 21 of Set 12 | svetlyy
# Processing Record 22 of Set 12 | stokmarknes
# Processing Record 23 of Set 12 | dargaville
# Processing Record 24 of Set 12 | bridlington
# Processing Record 25 of Set 12 | isiro
# Processing Record 26 of Set 12 | sam roi yot
# Processing Record 27 of Set 12 | bilibino
# Processing Record 28 of Set 12 | asau
# Processing Record 29 of Set 12 | tabou
# Processing Record 30 of Set 12 | wangqing
# Processing Record 31 of Set 12 | matara
# Processing Record 32 of Set 12 | xalpatlahuac
# Processing Record 33 of Set 12 | chupei
# City not found. Skipping...
# Processing Record 34 of Set 12 | linhai
# Processing Record 35 of Set 12 | hovd
# Processing Record 36 of Set 12 | konstantinovka
# Processing Record 37 of Set 12 | talcahuano
# Processing Record 38 of Set 12 | enid
# Processing Record 39 of Set 12 | gimbi
# Processing Record 40 of Set 12 | sandy bay
# Processing Record 41 of Set 12 | samalaeulu
# City not found. Skipping...
# Processing Record 42 of Set 12 | marathon
# Processing Record 43 of Set 12 | ulaangom
# Processing Record 44 of Set 12 | marapanim
# Processing Record 45 of Set 12 | bogalusa
# Processing Record 46 of Set 12 | kassala
# Processing Record 47 of Set 12 | bloemfontein
# Processing Record 48 of Set 12 | tumannyy
# City not found. Skipping...
# Processing Record 49 of Set 12 | kainantu
# Processing Record 50 of Set 12 | santa vitoria do palmar
# Processing Record 1 of Set 13 | gamboma
# Processing Record 2 of Set 13 | champasak
# Processing Record 3 of Set 13 | paralimni
# Processing Record 4 of Set 13 | corpus christi
# Processing Record 5 of Set 13 | yazman
# Processing Record 6 of Set 13 | saint-georges
# Processing Record 7 of Set 13 | mackay
# Processing Record 8 of Set 13 | belaya gora
# Processing Record 9 of Set 13 | thohoyandou
# Processing Record 10 of Set 13 | santa ines
# Processing Record 11 of Set 13 | hambantota
# Processing Record 12 of Set 13 | chernyakhiv
# Processing Record 13 of Set 13 | pustoshka
# Processing Record 14 of Set 13 | bayburt
# Processing Record 15 of Set 13 | maues
# Processing Record 16 of Set 13 | swan hill
# Processing Record 17 of Set 13 | madimba
# Processing Record 18 of Set 13 | waipawa
# Processing Record 19 of Set 13 | seredka
# Processing Record 20 of Set 13 | gizo
# Processing Record 21 of Set 13 | gabu
# Processing Record 22 of Set 13 | mlowo
# Processing Record 23 of Set 13 | tagusao
# Processing Record 24 of Set 13 | broken hill
# Processing Record 25 of Set 13 | develi
# Processing Record 26 of Set 13 | traverse city
# Processing Record 27 of Set 13 | mocambique
# City not found. Skipping...
# Processing Record 28 of Set 13 | usinsk
# Processing Record 29 of Set 13 | redmond
# Processing Record 30 of Set 13 | muravlenko
# Processing Record 31 of Set 13 | concepcion
# Processing Record 32 of Set 13 | peterhead
# Processing Record 33 of Set 13 | helong
# Processing Record 34 of Set 13 | batagay
# Processing Record 35 of Set 13 | pasighat
# Processing Record 36 of Set 13 | walvis bay
# Processing Record 37 of Set 13 | mandera
# Processing Record 38 of Set 13 | quatre cocos
# Processing Record 39 of Set 13 | villa bruzual
# Processing Record 40 of Set 13 | havre-saint-pierre
# Processing Record 41 of Set 13 | olenino
# Processing Record 42 of Set 13 | kurmanayevka
# Processing Record 43 of Set 13 | krasnovishersk
# Processing Record 44 of Set 13 | tselinnoye
# Processing Record 45 of Set 13 | rawannawi
# City not found. Skipping...
# Processing Record 46 of Set 13 | bambanglipuro
# Processing Record 47 of Set 13 | soyo
# Processing Record 48 of Set 13 | verkhnyaya toyma
# Processing Record 49 of Set 13 | perigueux
# Processing Record 50 of Set 13 | san ramon de la nueva oran
# Processing Record 1 of Set 14 | atar
# Processing Record 2 of Set 14 | port hedland
# Processing Record 3 of Set 14 | jinzhou
# Processing Record 4 of Set 14 | tazovskiy
# Processing Record 5 of Set 14 | itarema
# Processing Record 6 of Set 14 | gorontalo
# Processing Record 7 of Set 14 | sipkovica
# Processing Record 8 of Set 14 | port-gentil
# Processing Record 9 of Set 14 | san cristobal
# Processing Record 10 of Set 14 | henties bay
# Processing Record 11 of Set 14 | sur
# Processing Record 12 of Set 14 | manhattan
# Processing Record 13 of Set 14 | hervey bay
# Processing Record 14 of Set 14 | flagstaff
# Processing Record 15 of Set 14 | ixtapa
# Processing Record 16 of Set 14 | bulawayo
# Processing Record 17 of Set 14 | vestmannaeyjar
# Processing Record 18 of Set 14 | ewa beach
# Processing Record 19 of Set 14 | vadso
# Processing Record 20 of Set 14 | marsa matruh
# Processing Record 21 of Set 14 | kodinsk
# Processing Record 22 of Set 14 | alotau
# City not found. Skipping...
# Processing Record 23 of Set 14 | pacifica
# Processing Record 24 of Set 14 | chaman
# Processing Record 25 of Set 14 | cottonwood
# Processing Record 26 of Set 14 | weilheim
# Processing Record 27 of Set 14 | dalby
# Processing Record 28 of Set 14 | aden
# Processing Record 29 of Set 14 | kargopol
# Processing Record 30 of Set 14 | nome
# Processing Record 31 of Set 14 | saleaula
# City not found. Skipping...
# Processing Record 32 of Set 14 | viedma
# Processing Record 33 of Set 14 | terrak
# Processing Record 34 of Set 14 | banjarmasin
# Processing Record 35 of Set 14 | pokhara
# Processing Record 36 of Set 14 | nuuk
# Processing Record 37 of Set 14 | areado
# Processing Record 38 of Set 14 | okhotsk
# Processing Record 39 of Set 14 | la ronge
# Processing Record 40 of Set 14 | macaboboni
# City not found. Skipping...
# Processing Record 41 of Set 14 | kamenskoye
# City not found. Skipping...
# Processing Record 42 of Set 14 | utiroa
# City not found. Skipping...
# Processing Record 43 of Set 14 | jumla
# Processing Record 44 of Set 14 | ibra
# Processing Record 45 of Set 14 | sibu
# Processing Record 46 of Set 14 | takhtamygda
# Processing Record 47 of Set 14 | boppard
# Processing Record 48 of Set 14 | kununurra
# Processing Record 49 of Set 14 | pringsewu
# Processing Record 50 of Set 14 | qaqortoq
# Processing Record 1 of Set 15 | hay river
# Processing Record 2 of Set 15 | nador
# Processing Record 3 of Set 15 | tubmanburg
# Processing Record 4 of Set 15 | baracoa
# Processing Record 5 of Set 15 | severomuysk
# Processing Record 6 of Set 15 | port hardy
# Processing Record 7 of Set 15 | tori fatehpur
# Processing Record 8 of Set 15 | belen
# Processing Record 9 of Set 15 | araguaina
# Processing Record 10 of Set 15 | stepantsevo
# Processing Record 11 of Set 15 | narsaq
# Processing Record 12 of Set 15 | mattru
# Processing Record 13 of Set 15 | manokwari
# Processing Record 14 of Set 15 | carmen
# Processing Record 15 of Set 15 | faya
# Processing Record 16 of Set 15 | council bluffs
# Processing Record 17 of Set 15 | nouadhibou
# Processing Record 18 of Set 15 | skjervoy
# Processing Record 19 of Set 15 | molepolole
# Processing Record 20 of Set 15 | egvekinot
# Processing Record 21 of Set 15 | gat
# Processing Record 22 of Set 15 | abilene
# Processing Record 23 of Set 15 | kirovskiy
# Processing Record 24 of Set 15 | cedar city
# Processing Record 25 of Set 15 | kuybysheve
# Processing Record 26 of Set 15 | natal
# Processing Record 27 of Set 15 | ostrovskoye
# Processing Record 28 of Set 15 | sumbawa
# City not found. Skipping...
# Processing Record 29 of Set 15 | arrecife
# Processing Record 30 of Set 15 | kirkwall
# Processing Record 31 of Set 15 | fare
# Processing Record 32 of Set 15 | banjar
# Processing Record 33 of Set 15 | oranjemund
# Processing Record 34 of Set 15 | makhu
# Processing Record 35 of Set 15 | las cruces
# Processing Record 36 of Set 15 | dekar
# Processing Record 37 of Set 15 | aasiaat
# Processing Record 38 of Set 15 | mayo
# Processing Record 39 of Set 15 | yokadouma
# Processing Record 40 of Set 15 | trofors
# Processing Record 41 of Set 15 | lanzhou
# Processing Record 42 of Set 15 | inongo
# Processing Record 43 of Set 15 | shenkursk
# Processing Record 44 of Set 15 | conde
# Processing Record 45 of Set 15 | yining
# Processing Record 46 of Set 15 | nizhniy ingash
# Processing Record 47 of Set 15 | myaundzha
# Processing Record 48 of Set 15 | talnakh
# Processing Record 49 of Set 15 | muisne
# Processing Record 50 of Set 15 | huarmey
# Processing Record 1 of Set 16 | belawan
# Processing Record 2 of Set 16 | urengoy
# Processing Record 3 of Set 16 | praia
# Processing Record 4 of Set 16 | deputatskiy
# Processing Record 5 of Set 16 | mwingi
# Processing Record 6 of Set 16 | gwadar
# Processing Record 7 of Set 16 | yuzhno-yeniseyskiy
# City not found. Skipping...
# Processing Record 8 of Set 16 | oranjestad
# Processing Record 9 of Set 16 | artyk
# City not found. Skipping...
# Processing Record 10 of Set 16 | lalomanu
# City not found. Skipping...
# Processing Record 11 of Set 16 | puerto carreno
# Processing Record 12 of Set 16 | puerto leguizamo
# Processing Record 13 of Set 16 | nizwa
# Processing Record 14 of Set 16 | mbour
# Processing Record 15 of Set 16 | sebeta
# Processing Record 16 of Set 16 | sola
# Processing Record 17 of Set 16 | baruun-urt
# Processing Record 18 of Set 16 | khani
# Processing Record 19 of Set 16 | santa isabel do rio negro
# Processing Record 20 of Set 16 | damphu
# Processing Record 21 of Set 16 | ondorhaan
# City not found. Skipping...
# Processing Record 22 of Set 16 | montepuez
# Processing Record 23 of Set 16 | worland
# Processing Record 24 of Set 16 | kotri
# Processing Record 25 of Set 16 | savalou
# Processing Record 26 of Set 16 | kirakira
# Processing Record 27 of Set 16 | haimen
# Processing Record 28 of Set 16 | royan
# Processing Record 29 of Set 16 | outjo
# Processing Record 30 of Set 16 | wucheng
# Processing Record 31 of Set 16 | honningsvag
# Processing Record 32 of Set 16 | paita
# Processing Record 33 of Set 16 | salina cruz
# Processing Record 34 of Set 16 | khandyga
# Processing Record 35 of Set 16 | kabo
# Processing Record 36 of Set 16 | arman
# Processing Record 37 of Set 16 | cravo norte
# Processing Record 38 of Set 16 | matamoros
# Processing Record 39 of Set 16 | gangarampur
# Processing Record 40 of Set 16 | seddon
# Processing Record 41 of Set 16 | shirokiy
# Processing Record 42 of Set 16 | kazalinsk
# City not found. Skipping...
# Processing Record 43 of Set 16 | coldingham
# Processing Record 44 of Set 16 | teguldet
# Processing Record 45 of Set 16 | llanes
# Processing Record 46 of Set 16 | bodden town
# Processing Record 47 of Set 16 | alofi
# Processing Record 48 of Set 16 | albenga
# Processing Record 49 of Set 16 | barillas
# Processing Record 50 of Set 16 | rongcheng
# Processing Record 1 of Set 17 | ust-ilimsk
# -----------------------------
# Data Retrieval Complete
# -----------------------------

# %%
# Print the length of the city_data list to verify how many cities you have
len(city_data)
# Out:
# 753

# %% [markdown]
# ## Add the weather data to a new DataFrame.

# %%
# Use the city_data list to create a new pandas DataFrame.
city_data_df = pd.DataFrame(city_data)

# %%
# Display sample data
city_data_df.head(10)
# Out:
#              City      Lat       Lng  Max Temp  Humidity  Cloudiness  \
# 0          Khunti  23.0833   85.2833     62.71        57           3
# 1        Spornoye  50.8448   37.2913     27.41        55         100
# 2          Marion  39.7684  -86.1555     31.21        67          20
# 3          Castro -24.7911  -50.0119     69.10        80          97
# 4         Mataura -46.1927  168.8643     41.05        81          45
# 5          Baykit  61.6700   96.3700     -5.10        96         100
# 6       Busselton -33.6500  115.3333     60.57        94          13
# 7        Attingal   8.6833   76.8333     82.08        88          23
# 8         Rikitea -23.1203 -134.9692     72.23        72         100
# 9  Cabo San Lucas  22.8909 -109.9124     69.10        72          20
#
#    Wind Speed Country Current Description
# 0        4.74      IN           clear sky
# 1       14.36      RU     overcast clouds
# 2       19.57      US          few clouds
# 3        2.30      BR     overcast clouds
# 4        3.44      NZ    scattered clouds
# 5        6.22      RU     overcast clouds
# 6        7.76      AU          few clouds
# 7        3.42      IN          few clouds
# 8       12.39      PF     overcast clouds
# 9        6.91      MX          few clouds

# %%
# Display the DataFrame's column names using the columns Pandas function
city_data_df.columns
# Out:
# Index(['City', 'Lat', 'Lng', 'Max Temp', 'Humidity', 'Cloudiness',
#        'Wind Speed', 'Country', 'Current Description'],
#       dtype='object')

# %%
# Create a list to reorder the column names as follows:
# "City", "Country", "Lat", "Lng", "Max Temp", "Humidity",  "Cloudiness", "Wind Speed",  "Current Description"
new_column_order = ["City","Country","Lat","Lng","Max Temp","Humidity","Cloudiness","Wind Speed","Current Description"]

# Recreate the DataFrame by using the new column order
city_data_df = city_data_df[new_column_order]

# Round the "Lat" and "Lng" columns to two decimal places
city_data_df["Lat"] = city_data_df["Lat"].round(2)
city_data_df["Lng"] = city_data_df["Lng"].round(2)

# Display sample data
city_data_df.head()
# Out:
#        City Country    Lat     Lng  Max Temp  Humidity  Cloudiness  \
# 0    Khunti      IN  23.08   85.28     62.71        57           3
# 1  Spornoye      RU  50.84   37.29     27.41        55         100
# 2    Marion      US  39.77  -86.16     31.21        67          20
# 3    Castro      BR -24.79  -50.01     69.10        80          97
# 4   Mataura      NZ -46.19  168.86     41.05        81          45
#
#    Wind Speed Current Description
# 0        4.74           clear sky
# 1       14.36     overcast clouds
# 2       19.57          few clouds
# 3        2.30     overcast clouds
# 4        3.44    scattered clouds

# %%
# Display the data types of each column by using the dtypes Pandas function
city_data_df.dtypes
# Out:
# City                    object
# Country                 object
# Lat                    float64
# Lng                    float64
# Max Temp               float64
# Humidity                 int64
# Cloudiness               int64
# Wind Speed             float64
# Current Description     object
# dtype: object

# %% [markdown]
# ## Export the DataFrame as a CSV file, and save it as `WeatherPy_Database.csv` in the `Weather_Database` folder.

# %%
# Set the output file name
output_data_file = "WeatherPy_Database.csv"

# Export the city_data DataFrame into a CSV file
city_data_df.to_csv(output_data_file, index_label="City_ID")
