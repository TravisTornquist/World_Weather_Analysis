# %% [markdown]
# # Deliverable 2. Create a Customer Travel Destinations Map
#
# ----
#
# 1. Create a folder called `Vacation_Search` to save all the files related with this deliverable.
#
# 2. Download the `Vacation_Search_starter_code.ipynb` Jupyter notebook,save it into your `Vacation_Search folder`, and rename it as `Vacation_Search.ipynb`.
#
# 3. In the `Vacation_Search.ipynb` file, ensure that the dependencies and the Geoapify API key is imported correctly.
#
# 4. From the `Weather_Database` folder you created in the "Deliverable 1," import the `WeatherPy_Database.csv` file as a Pandas DataFrame named `city_data_df`.
#
# 5. Write two input statements that prompt the user to enter their minimum and maximum temperature criteria for their vacation.
#
# 6. Create a new Pandas DataFrame by using the `loc` Pandas method to filter the `city_data_df` DataFrame for temperature criteria  collected. Name the DataFrame as `preferred_cities_df`.
#
# 7. Create a new Pandas DataFrame named `clean_travel_cities` by using the Pandas `dropna` function on the `preferred_cities_df` to drop any empty rows.
#
# 8. Use the `copy` Pandas function to create a new DataFrame, called `hotel_df`, by copying the following columns from the `clean_travel_cities` DataFrame: "City", "Country", "Max Temp", "Current Description", "Lat", "Lng".
#
# 9. Add a new empty column named `Hotel Name` to the `hotel_df` DataFrame.
#
# 10. Review the hotel search parameters provided. These parameters are the same we used in this module; you'll use them to search for a hotel for each city.
#
# 11. Use a for loop to iterate through the `hotel_df` DataFrame. Retrieve the latitude and longitude of each city and use the Geoapify API to find the nearest hotel based on the search parameters provided, then add the hotel name to the `hotel_df` DataFrame. If a hotel isn't found, set the hotel name as "No hotel found".
#
# 12. Drop any rows in the `hotel_df` DataFrame where a hotel name is not found and store the resulting data into a new DataFrame named `clean_hotel_df`.
#
# 13. Create an CSV file to store the `clean_hotel_df` DataFrame as `WeatherPy_vacation.csv` in the Vacation_Search folder.
#
# 14. Use GeoViews to create a map that displays a point for every city in the `clean_hotel_df` DataFrame. In the point for each city add:
#
#     * The city name
#
#     * The country code
#
#     * The weather description
#
#     * The point's size should be the maximum temperature for the city
#
# 15. Take a screenshot of your map and save it to the `Vacation_Search` folder as `WeatherPy_vacation_map.png`.
#
# ---

# %% [markdown]
# ## Ensure that the dependencies and the Geoapify API key is imported correctly

# %%
# Dependencies and Setup
import hvplot.pandas
import pandas as pd
import requests

# Turn off warning messages
import warnings
warnings.filterwarnings("ignore")

# Import API key
from config import geoapify_key

# %% [markdown]
# ## From the `Weather_Database` folder you created in the "Deliverable 1," import the `WeatherPy_Database.csv` file as a Pandas DataFrame named `city_data_df`

# %%
# Import the WeatherPy_database.csv file. 
city_data_df = pd.read_csv("../Weather_Database/WeatherPy_Database.csv")

# Display sample data
city_data_df.head()
# Out:
#    City_ID      City Country    Lat     Lng  Max Temp  Humidity  Cloudiness  \
# 0        0    Khunti      IN  23.08   85.28     62.71        57           3
# 1        1  Spornoye      RU  50.84   37.29     27.41        55         100
# 2        2    Marion      US  39.77  -86.16     31.21        67          20
# 3        3    Castro      BR -24.79  -50.01     69.10        80          97
# 4        4   Mataura      NZ -46.19  168.86     41.05        81          45
#
#    Wind Speed Current Description
# 0        4.74           clear sky
# 1       14.36     overcast clouds
# 2       19.57          few clouds
# 3        2.30     overcast clouds
# 4        3.44    scattered clouds

# %% [markdown]
# ## Write two input statements that prompt the user to enter their minimum and maximum temperature criteria for their vacation

# %%
# Prompt the user to enter minimum and maximum temperature criteria.
min_temp = float(input("What is the minimum temperature you would like for your trip? "))
max_temp = float(input("What is the maximum temperature you would like for your trip? "))
# Out:
# What is the minimum temperature you would like for your trip? 55
# What is the maximum temperature you would like for your trip? 75

# %% [markdown]
# ## Create a new Pandas DataFrame by using the `loc` Pandas method to filter the `city_data_df` DataFrame for temperature criteria  collected. Name the DataFrame as `preferred_cities_df`

# %%
# Filter the city_data_df DataFrame to find the cities that fit the criteria using the loc method.
preferred_cities_df = city_data_df.loc[
    (city_data_df["Max Temp"] <= max_temp) & (city_data_df["Max Temp"] >= min_temp)]

# Display sample data
preferred_cities_df.head(10)
# Out:
#     City_ID            City Country    Lat     Lng  Max Temp  Humidity  \
# 0         0          Khunti      IN  23.08   85.28     62.71        57
# 3         3          Castro      BR -24.79  -50.01     69.10        80
# 6         6       Busselton      AU -33.65  115.33     60.57        94
# 8         8         Rikitea      PF -23.12 -134.97     72.23        72
# 9         9  Cabo San Lucas      MX  22.89 -109.91     69.10        72
# 12       12            Lebu      CL -37.62  -73.65     57.90        63
# 14       14         Shimoda      JP  34.67  138.95     57.11        81
# 20       20        Eatonton      US  33.33  -83.39     62.24        88
# 21       21      Mwinilunga      ZM -11.74   24.43     67.46        89
# 27       27         Ahipara      NZ -35.17  173.17     58.78        65
#
#     Cloudiness  Wind Speed Current Description
# 0            3        4.74           clear sky
# 3           97        2.30     overcast clouds
# 6           13        7.76          few clouds
# 8          100       12.39     overcast clouds
# 9           20        6.91          few clouds
# 12           8       20.58           clear sky
# 14          89       10.25     overcast clouds
# 20         100        7.38     overcast clouds
# 21         100        2.93       moderate rain
# 27          83       15.57       broken clouds

# %% [markdown]
# ## Create a new Pandas DataFrame named `clean_travel_cities` by using the Pandas `dropna` function on the `preferred_cities_df` to drop any empty rows

# %%
# Drop any empty rows and create a new DataFrame that doesn’t have empty rows.
clean__travel_cities = preferred_cities_df.dropna()

# Display sample data
clean__travel_cities.head(10)
# Out:
#     City_ID            City Country    Lat     Lng  Max Temp  Humidity  \
# 0         0          Khunti      IN  23.08   85.28     62.71        57
# 3         3          Castro      BR -24.79  -50.01     69.10        80
# 6         6       Busselton      AU -33.65  115.33     60.57        94
# 8         8         Rikitea      PF -23.12 -134.97     72.23        72
# 9         9  Cabo San Lucas      MX  22.89 -109.91     69.10        72
# 12       12            Lebu      CL -37.62  -73.65     57.90        63
# 14       14         Shimoda      JP  34.67  138.95     57.11        81
# 20       20        Eatonton      US  33.33  -83.39     62.24        88
# 21       21      Mwinilunga      ZM -11.74   24.43     67.46        89
# 27       27         Ahipara      NZ -35.17  173.17     58.78        65
#
#     Cloudiness  Wind Speed Current Description
# 0            3        4.74           clear sky
# 3           97        2.30     overcast clouds
# 6           13        7.76          few clouds
# 8          100       12.39     overcast clouds
# 9           20        6.91          few clouds
# 12           8       20.58           clear sky
# 14          89       10.25     overcast clouds
# 20         100        7.38     overcast clouds
# 21         100        2.93       moderate rain
# 27          83       15.57       broken clouds

# %% [markdown]
# ## Use the `copy` Pandas function to create a new DataFrame, called `hotel_df`, by copying the following columns from the `clean_travel_cities` DataFrame: "City", "Country", "Max Temp", "Current Description", "Lat", "Lng"

# %%
# Create DataFrame called hotel_df to store hotel names along with city, country, max temp, and coordinates.
hotel_df = preferred_cities_df[["City","Country","Max Temp","Current Description","Lat","Lng"]].copy()

# %% [markdown]
# ## Add a new empty column named `Hotel Name` to the `hotel_df` DataFrame

# %%
# Create a new column "Hotel Name".
hotel_df["Hotel Name"] = ""

# Display sample data
hotel_df.head()
# Out:
#              City Country  Max Temp Current Description    Lat     Lng  \
# 0          Khunti      IN     62.71           clear sky  23.08   85.28
# 3          Castro      BR     69.10     overcast clouds -24.79  -50.01
# 6       Busselton      AU     60.57          few clouds -33.65  115.33
# 8         Rikitea      PF     72.23     overcast clouds -23.12 -134.97
# 9  Cabo San Lucas      MX     69.10          few clouds  22.89 -109.91
#
#   Hotel Name
# 0
# 3
# 6
# 8
# 9

# %% [markdown]
# ## Review the hotel search parameters provided. These parameters are the same we used in this module; you'll use them to search for a hotel for each city

# %%
# Set parameters to search for a hotel
radius = 5000
params = {
    "categories":"accommodation.hotel",
    "apiKey": geoapify_key,
    "limit":20
}

# %% [markdown]
# ## Use a for loop to iterate through the `hotel_df` DataFrame. Retrieve the latitude and longitude of each city and use the Geoapify API to find the nearest hotel based on the search parameters provided, then add the hotel name to the `hotel_df` DataFrame. If a hotel isn't found, set the hotel name as "No hotel found"

# %%
# Iterate through the hotel DataFrame

# Print a message to follow up the hotel search
print("Starting hotel search")

# Iterate through the hotel_df DataFrame
for index, row in hotel_df.iterrows():
    # Get latitude and longitude from DataFrame.
    latitude = row["Lat"]
    longitude = row["Lng"]
    
    # Add the current city's latitude and longitude to the params dictionary
    params["filter"] = f"circle:{longitude},{latitude},{radius}"
    params["bias"] = f"proximity:{longitude},{latitude}"
    
    # Set up the base URL for the Geoapify Places API.
    base_url = "https://api.geoapify.com/v2/places"

    # Make request and retrieve the JSON data by using the params dictionaty
    name_address = requests.get(base_url, params=params)
    
    # Convert the API response to JSON format
    name_address = name_address.json()
    
    # Get the first hotel from the results and store the name, if a hotel isn't found set the hotel name as "No hotel found".
    try:
        hotel_df.loc[index, "Hotel Name"] = name_address["features"][0]["properties"]["name"]
    except (KeyError, IndexError):
        # If no hotel is found, set the hotel name as "No hotel found".
        hotel_df.loc[index, "Hotel Name"] = "No hotel found"
        
    # Log the search results
    print(f"{hotel_df.loc[index, 'City']} - nearest hotel: {hotel_df.loc[index, 'Hotel Name']}")

# Display sample data
hotel_df
# Out:
# Starting hotel search
# Khunti - nearest hotel: No hotel found
# Castro - nearest hotel: Grande Hotel
# Busselton - nearest hotel: Broadwater Beach Resort
# Rikitea - nearest hotel: Chez Bianca & Benoit
# Cabo San Lucas - nearest hotel: Hotel Estancia Real
# Lebu - nearest hotel: No hotel found
# Shimoda - nearest hotel: 黒船ホテル
# Eatonton - nearest hotel: No hotel found
# Mwinilunga - nearest hotel: No hotel found
# Ahipara - nearest hotel: YHA Ahipara
# Port Alfred - nearest hotel: No hotel found
# San Patricio - nearest hotel: No hotel found
# Ushuaia - nearest hotel: Apart Hotel Aires del Beagle
# Lixourion - nearest hotel: Palatino
# Erzin - nearest hotel: No hotel found
# Kapaa - nearest hotel: Coral Reef Resort
# Muros - nearest hotel: Hotel-Restaurante La Muradana
# Kiunga - nearest hotel: No hotel found
# Bowen - nearest hotel: No hotel found
# Hermanus - nearest hotel: Hermanus Backpackers
# Tocopilla - nearest hotel: hotel Isidora
# Pafos - nearest hotel: Axiothea
# Liaqatabad - nearest hotel: No hotel found
# Pisco - nearest hotel: Hospedaje
# Carnarvon - nearest hotel: No hotel found
# Port Lincoln - nearest hotel: Boston Hotel
# Elizabeth City - nearest hotel: Quality Inn
# Luderitz - nearest hotel: Seaview Hotel Zum Sperrgebiet
# Camabatela - nearest hotel: No hotel found
# Awjilah - nearest hotel: No hotel found
# Ojinaga - nearest hotel: Hotel
# Vila Franca Do Campo - nearest hotel: Vinha d'Areia Beach Hotel
# Airai - nearest hotel: No hotel found
# Ponta Do Sol - nearest hotel: Estalagem Ponta do Sol
# Jesup - nearest hotel: Days Inn
# Port Macquarie - nearest hotel: The Observatory
# Jalu - nearest hotel: فندق جالو السياحي
# Comodoro Rivadavia - nearest hotel: No hotel found
# Mar Del Plata - nearest hotel: Nuevo Ostende
# Coquimbo - nearest hotel: Hotel Liverpool
# Ribeira Grande - nearest hotel: No hotel found
# Charters Towers - nearest hotel: No hotel found
# Kadirli - nearest hotel: Karatepe Park Otel
# Lompoc - nearest hotel: Embassy Suites by Hilton Lompoc Central Coast
# Kineta - nearest hotel: Kinetta Beach Resort & Spa
# Ihosy - nearest hotel: HOTEL BIENVENUE
# Bredasdorp - nearest hotel: Victoria Hotel
# Hasaki - nearest hotel: Choshi Plaza Hotel
# Guerrero Negro - nearest hotel: Plaza sal paraiso
# Nanakuli - nearest hotel: No hotel found
# Trelew - nearest hotel: Hotel Galicia
# Aguimes - nearest hotel: Los Camellos
# Tres Arroyos - nearest hotel: Andrea Hotel
# Rio Gallegos - nearest hotel: Aire de Patagonia
# Tanda - nearest hotel: No hotel found
# Alexandria - nearest hotel: Hilton Alexandria Green Plaza
# Valparaiso - nearest hotel: Hotel Casa Higueras
# Kamina - nearest hotel: Hôtel DG
# Victoria - nearest hotel: 四季酒店 Four Seasons Hotel
# Hyeres - nearest hotel: Hôtel Les Orangers
# Wattegama - nearest hotel: No hotel found
# Cidreira - nearest hotel: Hotel Castelo
# Tandlianwala - nearest hotel: No hotel found
# Sarankhola - nearest hotel: No hotel found
# Denizli - nearest hotel: Anemon Denizli Otel
# Hendrina - nearest hotel: No hotel found
# Lufilufi - nearest hotel: No hotel found
# Arona - nearest hotel: Hotel Rural La Correa
# Cotacachi - nearest hotel: Hotel Garden La Mirage
# Moranbah - nearest hotel: No hotel found
# Mareeba - nearest hotel: The Gateway Hotel
# Westport - nearest hotel: Norwalk Inn and Conference Center
# Taltal - nearest hotel: Hostería Taltal
# Taunggyi - nearest hotel: Golden Island Cottages
# Sirjan - nearest hotel: هتل جهانگردی سیرجان
# East London - nearest hotel: Majestic Boutique Hotel
# Kapit - nearest hotel: Haip
# Frontera - nearest hotel: Quirino
# Narrabri - nearest hotel: Tattersall's Hotel
# Rawson - nearest hotel: Hotel Deportivo
# Tura - nearest hotel: No hotel found
# Pascagoula - nearest hotel: Grand Magnolia
# Villa Del Rosario - nearest hotel: San Diego
# Jinka - nearest hotel: No hotel found
# Nsanje - nearest hotel: No hotel found
# Constitucion - nearest hotel: Hotel Servicio de Salud del Maule
# Fandriana - nearest hotel: Hotel Sariaka
# Sakakah - nearest hotel: sakakah residence
# Lagoa - nearest hotel: Casa da Madrinha
# Flinders - nearest hotel: No hotel found
# Soe - nearest hotel: Hotel Bahagia 1
# Lima - nearest hotel: Hotel Peach Garden
# Byron Bay - nearest hotel: Lord Byron Resort
# Katsuura - nearest hotel: 潮騒の宿
# Sholapur - nearest hotel: No hotel found
# Odweyne - nearest hotel: فندق المدينه
# Necochea - nearest hotel: Cabañas Río Quequén
# San Roque - nearest hotel: Hotel Lagos
# Kasongo-Lunda - nearest hotel: No hotel found
# Ilebo - nearest hotel: Hôtel des Palmes
# Hun - nearest hotel: فندق الهروج
# Kindu - nearest hotel: No hotel found
# Avera - nearest hotel: No hotel found
# Villa Carlos Paz - nearest hotel: Arenales
# Tezu - nearest hotel: No hotel found
# Fereydun Kenar - nearest hotel: هتل کیش مهر
# Dubrovnik - nearest hotel: Hotel Lero
# Chicama - nearest hotel: No hotel found
# Ampanihy - nearest hotel: Hotel restaurant Angora
# Tripoli - nearest hotel: فندق الاصيل
# Makakilo City - nearest hotel: Embassy Suites by Hilton Oahu Kapolei
# Bilma - nearest hotel: No hotel found
# Namibe - nearest hotel: Hotel Chik Chik Namibe
# Yulara - nearest hotel: Outback Pioneer Hotel & Lodge
# Marawi - nearest hotel: Marawi Resort Hotel
# Bure - nearest hotel: belay zeleke hotel
# Bako - nearest hotel: Eyob Pension & Camp Site
# Abu Kamal - nearest hotel: No hotel found
# Wote - nearest hotel: Kelvin hotel;Kelvin Hotel
# Esperance - nearest hotel: Best Western
# Batemans Bay - nearest hotel: Esplanade Hotel
# Naze - nearest hotel: ビジネス旅館畠山
# Gold Coast - nearest hotel: The Sands
# Coihaique - nearest hotel: Hospedaje Bosque Patagón
# Carbonia - nearest hotel: Lu' Hotel
# Kanganpur - nearest hotel: No hotel found
# Hualmay - nearest hotel: Hotel Centenario
# Shurugwi - nearest hotel: No hotel found
# Olinda - nearest hotel: Fidji Motel
# Buta - nearest hotel: Hôtel Rubi
# Dubbo - nearest hotel: Ibis Budget
# Antibes - nearest hotel: Vogue
# Callaway - nearest hotel: Holiday Inn Express & Suites Panama City-Tyndall
# San Isidro - nearest hotel: Soul Mate
# Clifton - nearest hotel: La Quinta Inn & Suites Clifton - Rutherford
# Irbil - nearest hotel: Samira Miss Hotel
# Angoram - nearest hotel: No hotel found
# Dargaville - nearest hotel: Central Hotel
# Isiro - nearest hotel: Hôtel Mangreth
# Xalpatlahuac - nearest hotel: No hotel found
# Talcahuano - nearest hotel: Club Recreativo Armada de Chile
# Gimbi - nearest hotel: Grand hotel
# Bogalusa - nearest hotel: No hotel found
# Kainantu - nearest hotel: Kainantu Lodge
# Champasak - nearest hotel: Kiat Ngong Wetland
# Paralimni - nearest hotel: Apollon Court
# Corpus Christi - nearest hotel: Hotel Corpus Christi Bayfront
# Yazman - nearest hotel: Yazman Banquet Marriage Hall
# Mackay - nearest hotel: Mackay Oceanside Central Apartment Hotel
# Swan Hill - nearest hotel: No hotel found
# Mlowo - nearest hotel: EAST AFRICA LODGE
# Broken Hill - nearest hotel: Ibis Styles
# Concepcion - nearest hotel: Hotel Terrano
# Pasighat - nearest hotel: Aane Hotel
# San Cristobal - nearest hotel: Ciudadela
# Henties Bay - nearest hotel: Huis Klipdrift
# Manhattan - nearest hotel: La Quinta Inn
# Hervey Bay - nearest hotel: Hervey Bay Hotel
# Bulawayo - nearest hotel: Manor Hotel
# Ewa Beach - nearest hotel: Hampton Inn & Suites Oahu/Kapolei
# Marsa Matruh - nearest hotel: راضي
# Dalby - nearest hotel: No hotel found
# Viedma - nearest hotel: Peumayén
# Pokhara - nearest hotel: Kaushal Hotel
# Ibra - nearest hotel: الدكيك
# Sibu - nearest hotel: Towermas Hotel
# Pringsewu - nearest hotel: No hotel found
# Nador - nearest hotel: Hotel Lixus
# Tori Fatehpur - nearest hotel: No hotel found
# Faya - nearest hotel: No hotel found
# Nouadhibou - nearest hotel: Hotel valencia
# Gat - nearest hotel: No hotel found
# Arrecife - nearest hotel: Miramar
# Oranjemund - nearest hotel: No hotel found
# Makhu - nearest hotel: No hotel found
# Inongo - nearest hotel: Chez LELE IYOLO
# Huarmey - nearest hotel: Hospedaje Juanita
# Mwingi - nearest hotel: Greenvast Hotel
# Sebeta - nearest hotel: Tawabach Hotel
# Kotri - nearest hotel: Allah Badshah Restaurant
# Haimen - nearest hotel: No hotel found
# Paita - nearest hotel: Victor's
# Matamoros - nearest hotel: No hotel found
# Gangarampur - nearest hotel: No hotel found
# Seddon - nearest hotel: Palms Hotel
# Llanes - nearest hotel: Mira Olas
# Barillas - nearest hotel: Pensión el quetzal
#                City Country  Max Temp Current Description    Lat     Lng  \
# 0            Khunti      IN     62.71           clear sky  23.08   85.28
# 3            Castro      BR     69.10     overcast clouds -24.79  -50.01
# 6         Busselton      AU     60.57          few clouds -33.65  115.33
# 8           Rikitea      PF     72.23     overcast clouds -23.12 -134.97
# 9    Cabo San Lucas      MX     69.10          few clouds  22.89 -109.91
# ..              ...     ...       ...                 ...    ...     ...
# 740       Matamoros      MX     65.10           clear sky  25.53 -103.25
# 741     Gangarampur      IN     69.26           clear sky  25.40   88.52
# 742          Seddon      AU     56.61       broken clouds -37.81  144.89
# 746          Llanes      ES     57.88     overcast clouds  43.42   -4.75
# 750        Barillas      GT     70.45    scattered clouds  15.80  -91.32
#
#                   Hotel Name
# 0             No hotel found
# 3               Grande Hotel
# 6    Broadwater Beach Resort
# 8       Chez Bianca & Benoit
# 9        Hotel Estancia Real
# ..                       ...
# 740           No hotel found
# 741           No hotel found
# 742              Palms Hotel
# 746                Mira Olas
# 750       Pensión el quetzal
#
# [187 rows x 7 columns]

# %% [markdown]
# ## Drop any rows in the `hotel_df` DataFrame where a hotel name is not found and store the resulting data into a new DataFrame named `clean_hotel_df`

# %%
# Drop the rows where there is no Hotel Name.
clean_hotel_df = hotel_df[hotel_df["Hotel Name"] != "No hotel found"]

# Display sample data
clean_hotel_df.head(10)
# Out:
#               City Country  Max Temp Current Description    Lat     Lng  \
# 3           Castro      BR     69.10     overcast clouds -24.79  -50.01
# 6        Busselton      AU     60.57          few clouds -33.65  115.33
# 8          Rikitea      PF     72.23     overcast clouds -23.12 -134.97
# 9   Cabo San Lucas      MX     69.10          few clouds  22.89 -109.91
# 14         Shimoda      JP     57.11     overcast clouds  34.67  138.95
# 27         Ahipara      NZ     58.78       broken clouds -35.17  173.17
# 50         Ushuaia      AR     55.02       broken clouds -54.80  -68.30
# 54       Lixourion      GR     60.80       broken clouds  38.20   20.43
# 73           Kapaa      US     71.92    scattered clouds  22.08 -159.32
# 74           Muros      ES     56.08     overcast clouds  42.78   -9.06
#
#                        Hotel Name
# 3                    Grande Hotel
# 6         Broadwater Beach Resort
# 8            Chez Bianca & Benoit
# 9             Hotel Estancia Real
# 14                          黒船ホテル
# 27                    YHA Ahipara
# 50   Apart Hotel Aires del Beagle
# 54                       Palatino
# 73              Coral Reef Resort
# 74  Hotel-Restaurante La Muradana

# %% [markdown]
# ## Create an CSV file to store the `clean_hotel_df` DataFrame as `WeatherPy_vacation.csv` in the `Vacation_Search`` folder

# %%
# Create the output File (CSV)
output_data_file = "WeatherPy_vacation.csv"

# Export the City_Data into a csv
clean_hotel_df.to_csv(output_data_file, index_label="City_ID")

# %% [markdown]
# ## Use GeoViews to create a map that displays a point for every city in the `clean_hotel_df` DataFrame.
#
# In the point for each city add:
#
# * The city name
# * The country code
# * The weather description
# * The point's size should be the maximum temperature for the city

# %%
# Configure the map plot
hotel_map = clean_hotel_df.hvplot.points(
    "Lng",
    "Lat",
    geo = True,
    tiles = "OSM",
    frame_width = 700,
    frame_height = 500,
    size = "Max Temp",
    scale = 1,
    color = "City",
    hover_cols = ["City","Hotel Name","Country","Current Description"]
)

# Display the map
hotel_map
# Out:
# :Overlay
#    .Tiles.I  :Tiles   [x,y]
#    .Points.I :Points   [Lng,Lat]   (City,Max Temp,Hotel Name,Country,Current Description)
